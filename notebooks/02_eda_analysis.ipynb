# %% [markdown]
# # 02 EDA Analysis
# Quick exploratory plots for category and duration distributions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/processed/kaggle_processed.csv')
df['category'].value_counts().plot(kind='bar')
plt.show()
