# %% [markdown]
# # 03 Model Experiments
# Run quick Q-learning and DQN smoke training.

# %%
from src.training.train_q_learning import train_q_learning
_, rewards = train_q_learning(episodes=2)
rewards
